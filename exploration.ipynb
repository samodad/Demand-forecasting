# %%
import sys
import os

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# allow notebook to access src folder
sys.path.append("../src")

# %%
from data_preprocessing import load_data
from eda import plot_time_series, rolling_statistics
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from data_preprocessing import load_data
#       2 from eda import plot_time_series, rolling_statistics
#
# File c:\Samoda\KDU\3rd Year\Project\Demand forecasting\Notebooks\../src\data_preprocessing.py:1
# ----> 1 from data_preprocessing import load_data
#       3 df = load_data("C:\\Samoda\\KDU\\3rd Year\\Project\\Demand forecasting\\sales.csv")
#       5 print(df.head())
#
# ImportError: cannot import name 'load_data' from partially initialized module 'data_preprocessing' (most likely due to a circular import) (c:\Samoda\KDU\3rd Year\Project\Demand forecasting\Notebooks\../src\data_preprocessing.py)
